# %%
# !pip install flair

# %%
import pandas as pd
import flair

# %%
sentiment_model = flair.models.TextClassifier.load('en-sentiment')

# %%
sentence = flair.data.Sentence("Hello, I am very happy")
sentence

# %%
sentiment_model.predict(sentence)
sentence

# %%
sentence.labels

# %%
type(sentence.labels)

# %%
len(sentence.labels)

# %%
type(sentence.labels[0])

# %%
sentence.labels[0].value, sentence.labels[0].score
