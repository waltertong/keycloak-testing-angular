# %%
# !pip install mplfinance
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 1.8 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt

# %%
mtr = yf.download(tickers = '0066.HK', start='2020-01-01', end='2020-12-31')
mtr['20d']=np.round(mtr['Open'].rolling(20).mean(), 2)
mtr['40d']=np.round(mtr['Open'].rolling(40).mean(), 2)
plt.figure(figsize=(15,4))
plt.grid(True)
plt.plot(mtr[['Open', '20d', '40d']])
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# !pip install mplfinance

# %%
import mplfinance as mpf
mpf.plot(mtr, type='candle', style='charles', figratio=(10,6), mav=(20,40))

# %%
mpf.plot(mtr[:100], type='candle', style='charles', figratio=(10,6), mav=(20, 40), volume=True)
